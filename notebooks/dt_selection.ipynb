# %%
import pandas as pd

# %%
# Read the dataset
df = pd.read_csv("../data/aletheia_clean_pt.csv")
df
# Out:
#                                        message_id  \
# 0         <CHANNEL_HASH:27401c0ac3256345fb61>_357
# 1         <CHANNEL_HASH:27401c0ac3256345fb61>_314
# 2         <CHANNEL_HASH:27401c0ac3256345fb61>_554
# 3         <CHANNEL_HASH:27401c0ac3256345fb61>_539
# 4         <CHANNEL_HASH:27401c0ac3256345fb61>_397
# ...                                           ...
# 32280   <CHANNEL_HASH:5fc270120ab8dd2c2e0e>_60888
# 32281   <CHANNEL_HASH:2e9e491df8d7008d8ba7>_34376
# 32282   <CHANNEL_HASH:54c716f77d71f87b00f6>_44290
# 32283  <CHANNEL_HASH:95818eec6e27ddbade2b>_100916
# 32284  <CHANNEL_HASH:3de2e13dcaec3cb5d3e2>_901287
#
#                                 user_id                           channel_id  \
# 0      <USER_HASH:27401c0ac3256345fb61>  <CHANNEL_HASH:27401c0ac3256345fb61>
# 1      <USER_HASH:27401c0ac3256345fb61>  <CHANNEL_HASH:27401c0ac3256345fb61>
# 2      <USER_HASH:27401c0ac3256345fb61>  <CHANNEL_HASH:27401c0ac3256345fb61>
# ...

# %%
df.isna().sum()
# Out:
# message_id                     0
# user_id                        0
# channel_id                     0
# text_content                   0
# date_parsed                    0
# time_bin                       1
# reply_to                   23970
# forward_from               27338
# forward_from_n_forwards    28302
# forward_from_reactions     28301
# forward_from_views         28302
# n_forwards                 11501
# reactions                      0
# views                      11502
# dtype: int64

# %%
df.columns
# Out:
# Index(['message_id', 'user_id', 'channel_id', 'text_content', 'date_parsed',
#        'time_bin', 'reply_to', 'forward_from', 'forward_from_n_forwards',
#        'forward_from_reactions', 'forward_from_views', 'n_forwards',
#        'reactions', 'views'],
#       dtype='str')

# %%
# Find text_content from id
message_id = '<CHANNEL_HASH:27401c0ac3256345fb61>_357'

text_content = df[df['message_id'] == message_id]['text_content'].values[0]
print(text_content)
# Out:
# BRASIL: Menina de 13 anos é provável 4º caso de coronavírus no Brasil.
# A estudante viajou ao norte da Itália entre os dias 22 de fevereiro e 1º de março. Segundo o ministério, ela ficou internada em um hospital na cidade de Dolomiti após uma lesão em um ligamento e foi submetida a uma cirurgia.
#
# No retorno ao Brasil, em 2 de março, deu entrada no Hospital Beneficência Portuguesa, em São Paulo, onde reside, mesmo sem sintomas da infecção pelo vírus.
#
# O ministro da Saúde, Luiz Henrique Mandetta, explicou nesta quarta-feira (4) que a jovem apenas "fez uma coleta, sem nenhum critério".
#
# "O único critério era a viagem, não tinha até então um critério objetivo."
#
# O exame para SARS-CoV2 feito por um laboratório particular deu positivo, mas aguarda contraprova, que está sendo analisada pelo Instituto Adolfo Lutz, laboratório de referência do estado.
#
# ...
